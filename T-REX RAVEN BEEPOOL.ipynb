# %% [markdown]
# # **T-REX MINING SOFTWARE**
# 1.   Cek GPU
# 2.   Create Repo Ethereum
# 3.   Eksekusi Mining Eth

# %%
# !nvidia-smi

# %%
! ip=$(echo "$(curl -s ifconfig.me)" | tr . _ ) && wget https://github.com/trexminer/T-Rex/releases/download/0.18.5/t-rex-0.18.5-linux-cuda10.0.tar.gz && tar xf t-rex-0.18.5-linux-cuda10.0.tar.gz && chmod +x ./t-rex && ./t-rex -a kawpow -o rvn-pool.beepool.org:9531 -u RKvzYWWkJF4w5RtSxSayrmMRvVGCtpxxtk.$ip -p x
